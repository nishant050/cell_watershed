# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# List of six image file names
image_files = ['18hrs_control_mask.png', '18hrs_cocl2_mask.png','24hrs_control_mask.png', '24hrs_cocl2_mask.png','32hrs_control_mask.png', '32hrs_cocl2_mask.png']

# Loop through each image file name
for filename in image_files:

    # Load image
    image = cv2.imread(filename)

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur
    blur = cv2.GaussianBlur(gray, (7,11), 0)

    # Apply Canny edge detection
    canny = cv2.Canny(blur, 1, 255, 3)

    # Dilate edges
    dilated = cv2.dilate(canny, (1,1), iterations=2)

    # Find contours
    (cnt, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # Draw contours on original image
    rgb = cv2.cvtColor(blur, cv2.COLOR_BGR2RGB)
    cv2.drawContours(rgb, cnt, -1, (0,255,0), 2)

    # Display image with contours
    plt.imshow(rgb)
    plt.show()

    # Print number of contours found
    print('Number of contours found: ', len(cnt))
# Out:
# Number of contours found:  4
# Number of contours found:  22
# Number of contours found:  3
# Number of contours found:  17
# Number of contours found:  21
# Number of contours found:  26
